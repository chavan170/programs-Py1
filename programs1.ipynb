# %%
#Write a Python program to calculate the sum of all items of a container (tuple, list, set, dictionary).
def dict_sum(nums):
  num_sum = 0
  for i in nums:
       num_sum = num_sum + nums[i]
  return num_sum

nums = {'a': 100, 'b': 200, 'c': 300, 'd': 120}

print("Original container:")
print(nums)

print(type(nums))

print("Sum of all items of the said container:", dict_sum(nums))
# Out:
# Original container:
# {'a': 100, 'b': 200, 'c': 300, 'd': 120}
# <class 'dict'>
# Sum of all items of the said container: 720

# %%
#Write a python program to print without new line or space
for i in range(0, 10):

    print('python', end="")

print("\n")
# Out:
# pythonpythonpythonpythonpythonpythonpythonpythonpythonpython

# %%
#Write a python program to swap two variables
print("Input your height: ")

h_ft = int(input("Feet: "))


h_inch = int(input("Inches: "))


h_inch += h_ft * 12

h_cm = round(h_inch * 2.54, 1)


print("Your height is : %d cm." % h_cm)
# Out:
# Input your height:
# Feet: 6
# Inches: 23
# Your height is : 241 cm.

# %%
#Write a python program to swap two variables.
x = 34
y = 56

print("Initial Value of x =", x)
print("Initial Value of y =", y)

temp = x
x = y
y = temp

print("\nAfter swaping value of x =", x)
print("After swaping value of y =", y)
# Out:
# Initial Value of x = 34
# Initial Value of y = 56
#
# After swaping value of x = 56
# After swaping value of y = 34

# %%
#Write a python code to get all possible  two-digit letter combination from a 1-9 digit string
def letter_combinations(digits):
    # Check if the input string is empty.
    if digits == "":
        return []

    string_maps = {
        "1": "abc",
        "2": "def",
        "3": "ghi",
        "4": "jkl",
        "5": "mno",
        "6": "pqrs",
        "7": "tuv",
        "8": "wxy",
        "9": "z"
    }


    result = [""]


    for num in digits:

        temp = []


        for an in result:

            for char in string_maps[num]:
                temp.append(an + char)

        result = temp


    return result


digit_string = "47"
print(letter_combinations(digit_string))
digit_string = "29"
print(letter_combinations(digit_string))
# Out:
# ['jt', 'ju', 'jv', 'kt', 'ku', 'kv', 'lt', 'lu', 'lv']
# ['dz', 'ez', 'fz']

# %%
#Write a python program to check the sum of three elements (each from the array)from three array is equal to a target value print all those three elements combination
import itertools
from functools import partial


X = [10, 20, 20, 20]
Y = [10, 20, 30, 40]
Z = [10, 30, 40, 20]
T = 70

def check_sum_array(N, *nums):
    if sum(x for x in nums) == N:
        return (True, nums)
    else:
        return (False, nums)


pro = itertools.product(X, Y, Z)


func = partial(check_sum_array, T)


sums = list(itertools.starmap(func, pro))


result = set()


for s in sums:
    if s[0] == True and s[1] not in result:
        result.add(s[1])
        print(result)
# Out:
# {(10, 20, 40)}
# {(10, 30, 30), (10, 20, 40)}
# {(10, 30, 30), (10, 20, 40), (10, 40, 20)}
# {(10, 30, 30), (20, 10, 40), (10, 20, 40), (10, 40, 20)}
# {(10, 20, 40), (20, 20, 30), (20, 10, 40), (10, 40, 20), (10, 30, 30)}
# {(10, 20, 40), (20, 20, 30), (20, 10, 40), (10, 40, 20), (20, 30, 20), (10, 30, 30)}
# {(10, 20, 40), (20, 40, 10), (20, 20, 30), (20, 10, 40), (10, 40, 20), (20, 30, 20), (10, 30, 30)}
